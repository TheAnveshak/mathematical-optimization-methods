# %% [markdown]
# # Univariate Search Method

# %%
# !sage --version
# Out:
# SageMath version 10.5, Release Date: 2024-12-04

# %%
from sage.all import var, solve, N
from sage.all import *
import operator
import random

# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x, y, z, a, b = var('x y z a b')

# %%
func = lambda a, b: 6*a**2 - 6*a*b + 2*b**2 - a - 2*b

# %%
def axis_search(func, point, axis, step=1e-2): # search along e1 and e2

    t = var('t')
    coords = list(point)
    base_val = float(func(*coords))

    # +step along axis
    forward = float(func(*(coords[:axis] + [coords[axis] + step] + coords[axis+1:])))
    # -step along axis
    backward = float(func(*(coords[:axis] + [coords[axis] - step] + coords[axis+1:])))

    if forward < backward and forward < base_val:
        search = func(*(coords[:axis] + [coords[axis] + t] + coords[axis+1:]))
        direction = 1
    elif backward < forward and backward < base_val:
        search = func(*(coords[:axis] + [coords[axis] - t] + coords[axis+1:]))
        direction = -1
    else:
        return point

    sols = solve(search.diff(t) == 0, t)   # integrate funcs later
    if not sols:
        return point

    try:
        sol = sols[0].rhs()
    except:
        sol = sols[0]
    delta = float(N(sol)) * direction

    ### chatgpt : try next time
    ### delta = float(N(sols[0].rhs() if hasattr(sols[0], 'rhs') else sols[0])) * direction
    
    # update
    coords[axis] += delta
    
    return tuple(coords)

# %%
def univariate_search(func, init=(0, 0), tol=1e-6, max_iter=100):
    
    current = init
    for _ in range(max_iter):
        # along e1
        next_x = axis_search(func, current, axis=0)
        # now aong e2
        next_pt = axis_search(func, next_x, axis=1)

        move_mag = ((next_pt[0] - current[0])**2 + (next_pt[1] - current[1])**2)**0.5
        if move_mag < tol:
            break
        current = next_pt
    return current

# %%
t0 = (0.0, 0.0)
opt = univariate_search(func, init=t0)
print(f"Computed minimum at: {opt}")
# Out:
# Computed minimum at: (1.3166290070706357, 2.4749435106059536)

# %% [markdown]
# # MultiDimensional Function Solver

# %%
f = lambda a,b,c: a**2 + b**2 + c**2 - a - 2*b - 3*c

# %%
def multi_axis_search(func, point, axis, step=1e-2):
    t = var('t')
    coords = list(point)
    base = float(func(*coords))

    coords[axis] = point[axis] + step
    forward = float(func(*coords))
    coords[axis] = point[axis] - step
    backward = float(func(*coords))
    coords[axis] = point[axis]

    if forward < backward and forward < base:
        search = func(*(coords[:axis] + [point[axis] + t] + coords[axis+1:]))
        direction =  1
    elif backward < forward and backward < base:
        search = func(*(coords[:axis] + [point[axis] - t] + coords[axis+1:]))
        direction = -1
    else:
        return point

    sols = solve(search.diff(t) == 0, t)
    if not sols:
        return point

    try:
        sol = sols[0].rhs()
    except:
        sol = sols[0]
    delta = float(N(sol)) * direction

    coords[axis] = point[axis] + delta
    return tuple(coords)

# %%
def MD_univariate_search(func, init, tol=1e-6, max_iter=100):

    point = tuple(init)
    n = len(point)
    for _ in range(max_iter):
        for i in range(n):
            point = multi_axis_search(func, point, axis=i)
            
        shift = sum((point[i] - init[i])**2 for i in range(n))**0.5
        if shift < tol:
            break
        init = point
    return point

# %%
t0 = (0.0, 0.0,0.0)
opt = MD_univariate_search(f, init=t0)
print(f"Computed minimum at: {opt}")
# Out:
# Computed minimum at: (0.5, 1.0, 1.5)

# %% [markdown]
# # Tests

# %% [markdown]
# ### Sphere2D (0 0)

# %%
s = lambda x,y: x**2 + y**2

# %%
start = time.time()
res = MD_univariate_search(s, init=(0.5, -0.5), tol=1e-6, max_iter=200)
duration = time.time() - start
min = (0.00000, 0.00000) # known
error = np.linalg.norm(np.array(found) - np.array(true_min))

print(f"Found Minimum : {found}   ,  Error Norm : {error:.2e}   ,  Time (s) : {duration:.3f}")
# Out:
# Found Minimum : (0.0, 0.0)   ,  Error Norm : 1.41e+00   ,  Time (s) : 0.006

# %%
surface = plot3d(s, (x, -2, 2), (y, -2, 2) ,plot_points = 200, color='lightblue', opacity=0.8)
surface.show()
# Out:
# Graphics3d Object

# %%
min_dot = point3d((0, 0, 0), size=30, color='red', legend_label='Minimum')
min_dot.show()
# Out:
# Graphics3d Object

# %%
(surface + min_dot).show(frame=True, axes=True)
# Out:
# Graphics3d Object

# %%
# residuals = []
# point = (100)
# for i in range(15):
#     prev = point
#     point = axis_search(s, point, axis=i%2)
#     res = np.linalg.norm(np.array(point))
#     residuals.append(res)

# %%
# plt.figure()
# plt.plot(range(1, len(residuals)+1), residuals)
# plt.xlabel("Iteration")
# plt.ylabel("Residual (distance to origin)")
# plt.title("Convergence on Sphere 2D")
# plt.show()

# %% [markdown]
# ### Rosenbrock Banana Function  (1 1)

# %%
banana = lambda a,b: 100*(b - a**2)**2 + (1 - a)**2

# %%
start = time.time()
res = MD_univariate_search(b, init=(0.5, -0.5), tol=1e-6, max_iter=200)
duration = time.time() - start
min = (0.00000, 0.00000) # known
error = np.linalg.norm(np.array(found) - np.array(true_min))

print(f"Found Minimum : {found}   ,  Error Norm : {error:.2e}   ,  Time (s) : {duration:.3f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 start = time.time()
# ----> 2 res = MD_univariate_search(b, init=(0.5, -0.5), tol=1e-6, max_iter=200)
#       3 duration = time.time() - start
#       4 min = (0.00000, 0.00000) # known
#
# Cell In[14], line 7, in MD_univariate_search(func, init, tol, max_iter)
#       5 for _ in range(max_iter):
#       6     for i in range(n):
# ----> 7         point = multi_axis_search(func, point, axis=i)
#       9     shift = sum((point[i] - init[i])**2 for i in range(n))**0.5
#      10     if shift < tol:
#
# Cell In[13], line 4, in multi_axis_search(func, point, axis, step)
#       2 t = var('t')
#       3 coords = list(point)
# ----> 4 base = float(func(*coords))
#       6 coords[axis] = point[axis] + step
#       7 forward = float(func(*coords))
#
# File ~/sandBOX/sage-10.5/src/sage/symbolic/expression.pyx:6180, in sage.symbolic.expression.Expression.__call__()
#    6178         z^2 + x^y
#    6179     """
# -> 6180     return self._parent._call_element_(self, *args, **kwds)
#    6181
#    6182 def variables(self):
#
# File ~/sandBOX/sage-10.5/src/sage/symbolic/ring.pyx:1034, in sage.symbolic.ring.SymbolicRing._call_element_()
#    1032     d = args[0]
#    1033 else:
# -> 1034     raise TypeError("Substitution using function-call syntax "
#    1035                     "and unnamed arguments has been removed. You "
#    1036                     "can use named arguments instead, like "
#
# TypeError: Substitution using function-call syntax and unnamed arguments has been removed. You can use named arguments instead, like EXPR(x=..., y=...)

# %% [markdown]
# ### Rastringin  (0 0)

# %%
r = lambda a,b: 20 + a**2 - 10*np.cos(2*np.pi*a) + b**2 - 10*np.cos(2*np.pi*b)

# %%
start = time.time()
res = MD_univariate_search(b, init=(0.5, -0.5), tol=1e-6, max_iter=200)
duration = time.time() - start
min = (0.00000, 0.00000) # known
error = np.linalg.norm(np.array(found) - np.array(true_min))

print(f"Found Minimum : {found}   ,  Error Norm : {error:.2e}   ,  Time (s) : {duration:.3f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[138], line 2
#       1 start = time.time()
# ----> 2 res = MD_univariate_search(b, init=(0.5, -0.5), tol=1e-6, max_iter=200)
#       3 duration = time.time() - start
#       4 min = (0.00000, 0.00000) # known
#
# Cell In[125], line 7, in MD_univariate_search(func, init, tol, max_iter)
#       5 for _ in range(max_iter):
#       6     for i in range(n):
# ----> 7         point = multi_axis_search(func, point, axis=i)
#       9     shift = sum((point[i] - init[i])**2 for i in range(n))**0.5
#      10     if shift < tol:
#
# Cell In[124], line 29, in multi_axis_search(func, point, axis, step)
#      27 except:
#      28     sol = sols[0]
# ---> 29 delta = float(N(sol)) * direction
#      31 coords[axis] = point[axis] + delta
#      32 return tuple(coords)
#
# File ~/sandBOX/sage-10.5/src/sage/rings/complex_mpfr.pyx:1979, in sage.rings.complex_mpfr.ComplexNumber.__float__()
#    1977         return mpfr_get_d(self.__re, rnd)
#    1978     else:
# -> 1979         raise TypeError("unable to convert {!r} to float; use abs() or real_part() as desired".format(self))
#    1980
#    1981 def __complex__(self):
#
# TypeError: unable to convert 0.504949534628357 - 0.710685228268544*I to float; use abs() or real_part() as desired

# %% [markdown]
# ### Beale (3 2)

# %%
l = lambda a,b: (1.5 - a + a*b)**2 + (2.25 - a + a*b**2)**2 + (2.625 - a + a*b**3)**2

# %%
start = time.time()
res = MD_univariate_search(l, init=(0.5, -0.5), tol=1e-6, max_iter=200)
duration = time.time() - start
min = (0.00000, 0.00000) # known
error = np.linalg.norm(np.array(found) - np.array(true_min))

print(f"Found Minimum : {found}   ,  Error Norm : {error:.2e}   ,  Time (s) : {duration:.3f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[140], line 2
#       1 start = time.time()
# ----> 2 res = MD_univariate_search(l, init=(0.5, -0.5), tol=1e-6, max_iter=200)
#       3 duration = time.time() - start
#       4 min = (0.00000, 0.00000) # known
#
# Cell In[125], line 7, in MD_univariate_search(func, init, tol, max_iter)
#       5 for _ in range(max_iter):
#       6     for i in range(n):
# ----> 7         point = multi_axis_search(func, point, axis=i)
#       9     shift = sum((point[i] - init[i])**2 for i in range(n))**0.5
#      10     if shift < tol:
#
# Cell In[124], line 29, in multi_axis_search(func, point, axis, step)
#      27 except:
#      28     sol = sols[0]
# ---> 29 delta = float(N(sol)) * direction
#      31 coords[axis] = point[axis] + delta
#      32 return tuple(coords)
#
# File ~/sandBOX/sage-10.5/src/sage/misc/functional.py:1569, in numerical_approx(x, prec, digits, algorithm)
#    1567     return numerical_approx_generic(x, prec)
#    1568 else:
# -> 1569     return n(prec, algorithm=algorithm)
#
# File ~/sandBOX/sage-10.5/src/sage/symbolic/expression.pyx:6674, in sage.symbolic.expression.Expression.numerical_approx()
#    6672     res = x.pyobject()
#    6673 else:
# -> 6674     raise TypeError("cannot evaluate symbolic expression numerically")
#    6675
#    6676 # Important -- the  we get might not be a valid output for numerical_approx in
#
# TypeError: cannot evaluate symbolic expression numerically
